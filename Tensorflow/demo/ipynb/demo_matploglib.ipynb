# %% [markdown]
# # matplotlib
# * 画一个简单的图形
# * 在一张图纸上绘制多个图形
# * 添加注释
# * subplot
# * 散点图
# * 柱状图
# * 中文乱码问题解决方法
# * 基本图形绘制范例
# * 绘制图形框序列
# * 显示灰度图

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#fig=plt.figure()
#fig.suptitle('title')
#fig1,ax_lst=plt.subplots(2,2)


fig = plt.figure()  # an empty figure with no axes
fig.suptitle('No axes on this figure')  # Add a title so we know which it is

fig1, ax_lst = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

fig1 is fig
# Out:
# False

# %% [markdown]
# # 导入相关模块

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 画一个简单的图形

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,2*np.pi,50)
plt.plot(x,np.sin(x))
plt.grid()
plt.title('title')
plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.legend('x') #?
plt.show()

# %% [markdown]
# # 在一张图纸上绘制多个图形

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,2*np.pi,50)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,label="y1")
plt.plot(x,y2,label="y2")
plt.legend()
plt.show()

# %% [markdown]
# # 添加注释

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(0,2*np.pi,50)
y=np.sin(x)
plt.plot(x, y)
x0 = np.pi
y0 = 0

# 画出标注点
plt.scatter(x0, y0, s=50)

plt.annotate('sin(np.pi)=%s' % y0, xy=(x0, y0), xycoords='data', xytext=(+30, -30),
             textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle='->', connectionstyle="arc3,rad=.2"))

plt.text(0.5, -0.25, "sin(np.pi) = 0", fontdict={'size': 16, 'color': 'r'})

plt.show()

# %% [markdown]
# # 添加子图

# %%
ax1 = plt.subplot(2, 2, 1) # （行，列，活跃区）
plt.plot(x, np.sin(x), 'r')

ax2 = plt.subplot(2, 2, 2, sharey=ax1) # 与 ax1 共享y轴
plt.plot(x, 2 * np.sin(x), 'g')

ax3 = plt.subplot(2, 2, 3)
plt.plot(x, np.cos(x), 'b')

ax4 = plt.subplot(2, 2, 4, sharey=ax3) # 与 ax3 共享y轴
plt.plot(x, 2 * np.cos(x), 'y')

plt.show()

# %%
ax1 = plt.subplot(2, 1, 1) # （行，列，活跃区）
plt.plot(x, np.sin(x), 'r')

ax2 = plt.subplot(2, 3, 4)
plt.plot(x, 2 * np.sin(x), 'g')

ax3 = plt.subplot(2, 3, 5, sharey=ax2)
plt.plot(x, np.cos(x), 'b')

ax4 = plt.subplot(2, 3, 6, sharey=ax2)
plt.plot(x, 2 * np.cos(x), 'y')

plt.show()

# %% [markdown]
# # 散点图

# %%
k = 500
x = np.random.rand(k) 
y = np.random.rand(k)
size = np.random.rand(k) * 50 # 生成每个点的大小
colour = np.arctan2(x, y) # 生成每个点的颜色大小
#print(colour)
plt.scatter(x, y, s=size, c=colour)
plt.colorbar() # 添加颜色栏

plt.show()

# %% [markdown]
# # 柱状图

# %%
k = 10
x = np.arange(k)
y = np.random.rand(k)
plt.bar(x, y) # 画出 x 和 y 的柱状图

# 增加数值
for x, y in zip(x, y):
    plt.text(x, y , '%.2f' % y, ha='center', va='bottom')

plt.show()

# %% [markdown]
# # 中文乱码解决方法
#
# https://blog.csdn.net/huuinn/article/details/78968966
#
# * 下载中文字体 SIMHEI.tff
#
#     http://www.font5.com.cn/font_download.php?id=151&part=1237887120
#
# * 把字体拷贝到：/usr/local/lib/python3.5/dist-packages/matplotlib/mpl-data/fonts/ttf/
#
# * 永久生效配置方法
#
#     - 修改配置/usr/local/lib/python*/dist-packages/matplotlib/mpl-data/matplotlibrc文件
#     - 搜索font.family配置项，将其#注释去掉，并将：号后面的值改为字段对应的名字。
#     - font.family         : SimHei
#     - 搜索axes.unicode_minus配置项，将其#注释去掉，并将：号后面的值改为False
#     - axes.unicode_minus  : False
#     - 保存退出
#     - 清空matplotlib使配置生效
#     - $rm ~/.cache/matplotlib -R
#
# * 当前临时生效设置方法
#     - plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
#     - plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
#
# * 显示当前系统安装字体
#     - $fc-list :lang=zh-cn

# %%
x = ['北京', '上海', '深圳', '广州']
y = [60000, 58000, 50000, 52000]
plt.plot(x, y)
plt.show()

# %%
#/usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#  (prop.get_family(), self.defaultFamily[fontext]))
#plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
#plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

plt.plot(x, y)
plt.show()

# %% [markdown]
# # 基本图形绘制范例
#  * 点
#  * 直线
#  * 正方形/长方形
#  * 圆形
#  * 椭圆
#  * 扇形
#  *

# %%
#画点
#plt.scatter(x, y, s=size, c=colour)
x=[1,10,30]
y=[20,5,20]
plt.scatter(x,y)

# %%
#画直线
x=[1,20]
y=[1,20]
plt.plot(x,y)
plt.show()

# %%
#路径绘制
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches

verts = [
   (0., 0.),  # left, bottom
   (0., 1.),  # left, top
   (1., 1.),  # right, top
   (1., 0.),  # right, bottom
   (0., 0.),  # ignored
]

codes = [
    Path.MOVETO,
    Path.LINETO,
    Path.LINETO,
    Path.LINETO,
    Path.CLOSEPOLY,
]

path = Path(verts, codes)

fig, ax = plt.subplots()
patch = patches.PathPatch(path, facecolor='orange', lw=2)
ax.add_patch(patch)
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
plt.show()

# %%
#画矩形
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
x=1
y=2
w=10
h=20

fig, ax = plt.subplots()
ax.add_patch(patches.Rectangle((x,y),w,h,fill=False,lw=1,color='red'))
ax.set_xlim(-10, 30)
ax.set_ylim(-10, 30)
plt.grid()
plt.show()

# %% [markdown]
# # 绘制矩形框序列

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
#在一张图像上绘制矩形框序列
def DrawBoxs(img,boxs,texts=None,colors=None):
    #fig, ax = plt.subplots()
    plt.imshow(img)
    ax=plt.gca()
    for i,box in enumerate(boxs):
        x=box[0]
        y=box[1]
        w=box[2]-box[0]
        h=box[3]-box[1]
        text=texts[i]
        color='red' if colors is None else colors[i]
        
        ax.add_patch(patches.Rectangle((x,y),w,h,fill=False,lw=1,color=color))
        plt.text(x, y, text, fontdict={'size': 16, 'color': color})
    #ax.set_xlim(x_min, x_max)
    #ax.set_ylim(y_min, y_max)
    return img

# %%
boxs=np.array(
    [
        [10,10,50,80],
        [40,40,90,70],        
    ]
    )
titles=['a','b']
img=np.zeros((100,200,3),dtype=np.uint8)
img=DrawBoxs(img,boxs,texts=titles,colors=['red','green'])
plt.imshow(img)
# Out:
# ['__annotations__', '__call__', '__class__', '__closure__', '__code__', '__defaults__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__globals__', '__gt__', '__hash__', '__init__', '__kwdefaults__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %% [markdown]
# ## 显示灰度图

# %%
import numpy as np
import matplotlib.pyplot as plt

data=np.random.randint(0,256,size=(600,400),dtype=np.uint8)
plt.subplot(1,2,1)
plt.imshow(data)
plt.subplot(1,2,2)
plt.imshow(data,cmap=plt.cm.gray)
