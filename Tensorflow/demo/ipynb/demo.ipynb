# %%
# %matplotlib inline
import os
from skimage import io

img=io.imread('%s/work/data/gtest/1.jpg'%(os.getenv('HOME')))
io.imshow(img)
io.show()

# %%
def funs(n,*args):
    for arg in args:
        print(arg)
        
funs(1,(1,2),(3,4))
# Out:
# (1, 2)
# (3, 4)
