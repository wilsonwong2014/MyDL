# %%
import os
from PIL import Image
import numpy as np
from matplotlib.colors import rgb_to_hsv, hsv_to_rgb
import matplotlib.pyplot as plt

# %%
def letterbox_image(image, size):
    '''resize image with unchanged aspect ratio using padding'''
    iw, ih = image.size
    w, h = size
    scale = min(w/iw, h/ih)
    nw = int(iw*scale)
    nh = int(ih*scale)

    image = image.resize((nw,nh), Image.BICUBIC)
    new_image = Image.new('RGB', size, (128,128,128))
    new_image.paste(image, ((w-nw)//2, (h-nh)//2))
    return new_image

# %%
img_file='%s/data/1.jpg'%(os.getenv('HOME'))
image = Image.open(img_file)    #=>img_file
iw, ih = image.size            #=>(486,500)尺寸大小不固定

print('image.size:',image.size)
plt.imshow(image)
plt.show()

print('letterbox_image:')
new_image=letterbox_image(image,(100,200))
print('new_image.size:',new_image.size)
plt.imshow(new_image)
plt.show()
# Out:
# image.size: (200, 200)
# letterbox_image:
# new_image.size: (100, 200)
